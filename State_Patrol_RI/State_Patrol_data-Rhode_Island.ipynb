# %% [markdown]
# # Importing libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
#loading the Traffic police dataset for Rhode Islands
df=pd.read_csv("datasets/traffic-RI.csv")
df.head()
# Out:
#    raw_row_number        date      time zone subject_race subject_sex  \
# 0               1  2005-11-22  11:15:00   X3        white        male
# 1               2  2005-10-01  12:20:00   X3        white        male
# 2               3  2005-10-01  12:30:00   X3        white      female
# 3               4  2005-10-01  12:50:00   X3        white        male
# 4               5  2005-10-01  13:10:00   X3        white      female
#
#   department_id       type arrest_made citation_issued warning_issued  \
# 0           200  vehicular       False            True          False
# 1           200  vehicular       False            True          False
# 2           200  vehicular       False            True          False
# 3           200  vehicular       False            True          False
# 4           200  vehicular       False            True          False
#
#     outcome contraband_found contraband_drugs contraband_weapons  \
# 0  citation              NaN              NaN                NaN
# 1  citation              NaN              NaN                NaN
# 2  citation              NaN              NaN                NaN
# 3  citation              NaN              NaN                NaN
# 4  citation              NaN              NaN                NaN
#
#   contraband_alcohol contraband_other frisk_performed  search_conducted  \
# 0                NaN              NaN           False             False
# 1                NaN              NaN           False             False
# 2                NaN              NaN           False             False
# 3                NaN              NaN           False             False
# 4                NaN              NaN           False             False
#
#   search_basis reason_for_search reason_for_stop vehicle_make vehicle_model  \
# 0          NaN               NaN        Speeding          NaN           NaN
# 1          NaN               NaN        Speeding          NaN           NaN
# 2          NaN               NaN        Speeding          NaN           NaN
# 3          NaN               NaN        Speeding          NaN           NaN
# 4          NaN               NaN        Speeding          NaN           NaN
#
#   raw_BasisForStop raw_OperatorRace raw_OperatorSex raw_ResultOfStop  \
# 0               SP                W               M                M
# 1               SP                W               M                M
# 2               SP                W               F                M
# 3               SP                W               M                M
# 4               SP                W               F                M
#
#   raw_SearchResultOne raw_SearchResultTwo raw_SearchResultThree
# 0                 NaN                 NaN                   NaN
# 1                 NaN                 NaN                   NaN
# 2                 NaN                 NaN                   NaN
# 3                 NaN                 NaN                   NaN
# 4                 NaN                 NaN                   NaN

# %% [markdown]
# # Getting to know the data

# %%
df.dtypes
# Out:
# raw_row_number            int64
# date                     object
# time                     object
# zone                     object
# subject_race             object
# subject_sex              object
# department_id            object
# type                     object
# arrest_made              object
# citation_issued          object
# warning_issued           object
# outcome                  object
# contraband_found         object
# contraband_drugs         object
# contraband_weapons       object
# contraband_alcohol       object
# contraband_other         object
# frisk_performed          object
# search_conducted           bool
# search_basis             object
# reason_for_search        object
# reason_for_stop          object
# vehicle_make             object
# vehicle_model            object
# raw_BasisForStop         object
# raw_OperatorRace         object
# raw_OperatorSex          object
# raw_ResultOfStop         object
# raw_SearchResultOne      object
# raw_SearchResultTwo      object
# raw_SearchResultThree    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509681 entries, 0 to 509680
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   raw_row_number         509681 non-null  int64
#  1   date                   509671 non-null  object
#  2   time                   509671 non-null  object
#  3   zone                   509671 non-null  object
#  4   subject_race           480608 non-null  object
#  5   subject_sex            480584 non-null  object
#  6   department_id          509671 non-null  object
#  7   type                   509681 non-null  object
#  8   arrest_made            480608 non-null  object
#  9   citation_issued        480608 non-null  object
#  10  warning_issued         480608 non-null  object
#  11  outcome                473840 non-null  object
#  12  contraband_found       17762 non-null   object
#  13  contraband_drugs       15988 non-null   object
#  14  contraband_weapons     11795 non-null   object
#  15  contraband_alcohol     1217 non-null    object
#  16  contraband_other       17762 non-null   object
#  17  frisk_performed        509671 non-null  object
#  18  search_conducted       509681 non-null  bool
#  19  search_basis           17762 non-null   object
#  20  reason_for_search      17762 non-null   object
#  21  reason_for_stop        480608 non-null  object
#  22  vehicle_make           318117 non-null  object
#  23  vehicle_model          230088 non-null  object
#  24  raw_BasisForStop       480608 non-null  object
#  25  raw_OperatorRace       480608 non-null  object
#  26  raw_OperatorSex        480608 non-null  object
#  27  raw_ResultOfStop       480608 non-null  object
#  28  raw_SearchResultOne    17762 non-null   object
#  29  raw_SearchResultTwo    819 non-null     object
#  30  raw_SearchResultThree  168 non-null     object
# dtypes: bool(1), int64(1), object(29)
# memory usage: 117.1+ MB

# %%
df.isnull().sum()
# Out:
# raw_row_number                0
# date                         10
# time                         10
# zone                         10
# subject_race              29073
# subject_sex               29097
# department_id                10
# type                          0
# arrest_made               29073
# citation_issued           29073
# warning_issued            29073
# outcome                   35841
# contraband_found         491919
# contraband_drugs         493693
# contraband_weapons       497886
# contraband_alcohol       508464
# contraband_other         491919
# frisk_performed              10
# search_conducted              0
# search_basis             491919
# reason_for_search        491919
# reason_for_stop           29073
# vehicle_make             191564
# vehicle_model            279593
# raw_BasisForStop          29073
# raw_OperatorRace          29073
# raw_OperatorSex           29073
# raw_ResultOfStop          29073
# raw_SearchResultOne      491919
# raw_SearchResultTwo      508862
# raw_SearchResultThree    509513
# dtype: int64

# %%
df.describe() # this will not be accurate untill we convert data types
# Out:
#        raw_row_number
# count   509681.000000
# mean    254841.000000
# std     147132.375613
# min          1.000000
# 25%     127421.000000
# 50%     254841.000000
# 75%     382261.000000
# max     509681.000000

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Converting the categorical features

# %%
continous=[]
categorical=[]
def convert_type(a):
    n=df[a].nunique()
    if n > 20:
        continous.append(a)
    else:
        categorical.append(a)

# %%
for index,i in enumerate(df.columns):
    convert_type(i)

# %%
continous
# Out:
# ['raw_row_number',
#  'date',
#  'time',
#  'department_id',
#  'reason_for_search',
#  'vehicle_make',
#  'vehicle_model']

# %%
categorical
# Out:
# ['zone',
#  'subject_race',
#  'subject_sex',
#  'type',
#  'arrest_made',
#  'citation_issued',
#  'warning_issued',
#  'outcome',
#  'contraband_found',
#  'contraband_drugs',
#  'contraband_weapons',
#  'contraband_alcohol',
#  'contraband_other',
#  'frisk_performed',
#  'search_conducted',
#  'search_basis',
#  'reason_for_stop',
#  'raw_BasisForStop',
#  'raw_OperatorRace',
#  'raw_OperatorSex',
#  'raw_ResultOfStop',
#  'raw_SearchResultOne',
#  'raw_SearchResultTwo',
#  'raw_SearchResultThree']

# %%
df[categorical].iloc[-20:]
# Out:
#        zone subject_race subject_sex       type arrest_made citation_issued  \
# 509661   X1          NaN         NaN  vehicular         NaN             NaN
# 509662   X1          NaN         NaN  vehicular         NaN             NaN
# 509663   X3        white      female  vehicular       False            True
# 509664   K2        white        male  vehicular       False            True
# 509665   K2        white      female  vehicular       False            True
# 509666   K2     hispanic        male  vehicular       False            True
# 509667   X1          NaN         NaN  vehicular         NaN             NaN
# 509668   X4     hispanic        male  vehicular       False            True
# 509669   X4          NaN         NaN  vehicular         NaN             NaN
# 509670   X4        white        male  vehicular       False            True
# 509671   X4        white        male  vehicular       False            True
# 509672   K2        white        male  vehicular       False            True
# 509673   K2        white      female  vehicular       False            True
# 509674   X4          NaN         NaN  vehicular         NaN             NaN
# 509675   X1        white      female  vehicular       False           False
# 509676   X3        white        male  vehicular       False            True
# 509677   K3        white      female  vehicular       False            True
# 509678   X4        white        male  vehicular       False           False
# 509679   X4        white      female  vehicular       False            True
# 509680  NaN          NaN         NaN  vehicular         NaN             NaN
#
#        warning_issued   outcome contraband_found contraband_drugs  \
# 509661            NaN       NaN              NaN              NaN
# 509662            NaN       NaN              NaN              NaN
# 509663          False  citation              NaN              NaN
# 509664          False  citation              NaN              NaN
# 509665          False  citation              NaN              NaN
# 509666          False  citation              NaN              NaN
# 509667            NaN       NaN              NaN              NaN
# 509668          False  citation              NaN              NaN
# 509669            NaN       NaN              NaN              NaN
# 509670          False  citation              NaN              NaN
# 509671          False  citation              NaN              NaN
# 509672          False  citation              NaN              NaN
# 509673          False  citation              NaN              NaN
# 509674            NaN       NaN              NaN              NaN
# 509675          False       NaN              NaN              NaN
# 509676          False  citation              NaN              NaN
# 509677          False  citation              NaN              NaN
# 509678           True   warning              NaN              NaN
# 509679          False  citation              NaN              NaN
# 509680            NaN       NaN              NaN              NaN
#
#        contraband_weapons contraband_alcohol contraband_other frisk_performed  \
# 509661                NaN                NaN              NaN           False
# 509662                NaN                NaN              NaN           False
# 509663                NaN                NaN              NaN           False
# 509664                NaN                NaN              NaN           False
# 509665                NaN                NaN              NaN           False
# 509666                NaN                NaN              NaN           False
# 509667                NaN                NaN              NaN           False
# 509668                NaN                NaN              NaN           False
# 509669                NaN                NaN              NaN           False
# 509670                NaN                NaN              NaN           False
# 509671                NaN                NaN              NaN           False
# 509672                NaN                NaN              NaN           False
# 509673                NaN                NaN              NaN           False
# 509674                NaN                NaN              NaN           False
# 509675                NaN                NaN              NaN           False
# 509676                NaN                NaN              NaN           False
# 509677                NaN                NaN              NaN           False
# 509678                NaN                NaN              NaN           False
# 509679                NaN                NaN              NaN           False
# 509680                NaN                NaN              NaN             NaN
#
#         search_conducted search_basis                 reason_for_stop  \
# 509661             False          NaN                             NaN
# 509662             False          NaN                             NaN
# 509663             False          NaN         Other Traffic Violation
# 509664             False          NaN                        Speeding
# 509665             False          NaN                        Speeding
# 509666             False          NaN                        Speeding
# 509667             False          NaN                             NaN
# 509668             False          NaN  Equipment/Inspection Violation
# 509669             False          NaN                             NaN
# 509670             False          NaN                        Speeding
# 509671             False          NaN                        Speeding
# 509672             False          NaN                        Speeding
# 509673             False          NaN         Other Traffic Violation
# 509674             False          NaN                             NaN
# 509675             False          NaN  Equipment/Inspection Violation
# 509676             False          NaN  Equipment/Inspection Violation
# 509677             False          NaN                        Speeding
# 509678             False          NaN  Equipment/Inspection Violation
# 509679             False          NaN                        Speeding
# 509680             False          NaN                             NaN
#
#        raw_BasisForStop raw_OperatorRace raw_OperatorSex raw_ResultOfStop  \
# 509661              NaN              NaN             NaN              NaN
# 509662              NaN              NaN             NaN              NaN
# 509663               OT                W               F                M
# 509664               SP                W               M                M
# 509665               SP                W               F                M
# 509666               SP                H               M                M
# 509667              NaN              NaN             NaN              NaN
# 509668               EQ                H               M                M
# 509669              NaN              NaN             NaN              NaN
# 509670               SP                W               M                M
# 509671               SP                W               M                M
# 509672               SP                W               M                M
# 509673               OT                W               F                M
# 509674              NaN              NaN             NaN              NaN
# 509675               EQ                W               F                N
# 509676               EQ                W               M                M
# 509677               SP                W               F                M
# 509678               EQ                W               M                W
# 509679               SP                W               F                M
# 509680              NaN              NaN             NaN              NaN
#
#        raw_SearchResultOne raw_SearchResultTwo raw_SearchResultThree
# 509661                 NaN                 NaN                   NaN
# 509662                 NaN                 NaN                   NaN
# 509663                 NaN                 NaN                   NaN
# 509664                 NaN                 NaN                   NaN
# 509665                 NaN                 NaN                   NaN
# 509666                 NaN                 NaN                   NaN
# 509667                 NaN                 NaN                   NaN
# 509668                 NaN                 NaN                   NaN
# 509669                 NaN                 NaN                   NaN
# 509670                 NaN                 NaN                   NaN
# 509671                 NaN                 NaN                   NaN
# 509672                 NaN                 NaN                   NaN
# 509673                 NaN                 NaN                   NaN
# 509674                 NaN                 NaN                   NaN
# 509675                 NaN                 NaN                   NaN
# 509676                 NaN                 NaN                   NaN
# 509677                 NaN                 NaN                   NaN
# 509678                 NaN                 NaN                   NaN
# 509679                 NaN                 NaN                   NaN
# 509680                 NaN                 NaN                   NaN

# %%
def print_unique(a):
    for i in a:
        print(df[i].unique())

# %%
print_unique(categorical)
# Out:
# ['X3' 'X4' 'K3' 'K2' 'K1' 'X1' nan]
# ['white' 'hispanic' 'black' 'other' 'asian/pacific islander' nan]
# ['male' 'female' nan]
# ['vehicular']
# [False True nan]
# [True False nan]
# [False True nan]
# ['citation' nan 'arrest' 'warning']
# [nan False True]
# [nan False True]
# [nan False True]
# [nan False True]
# [nan False True]
# [False True nan]
# [False  True]
# [nan 'other' 'probable cause' 'plain view']
# ['Speeding' 'Other Traffic Violation' 'Equipment/Inspection Violation'
#  'Motorist Assist/Courtesy' 'Registration Violation' 'Call for Service'
#  nan 'Violation of City/Town Ordinance' 'Special Detail/Directed Patrol'
#  'APB' 'Warrant' 'Suspicious Person' 'Seatbelt Violation']
# ['SP' 'OT' 'EQ' 'MO' 'RV' 'CS' nan 'VO' 'SD' 'AP' 'WA' 'SU' 'SB']
# ['W' 'H' 'B' 'O' 'I' 'N' nan 'L']
# ['M' 'F' nan 'N' 'U']
# ['M' 'N' 'D' 'P' 'W' nan 'A']
# [nan 'N' 'D' 'M' 'A' 'W' 'O']
# [nan 'W' 'D' 'A' 'O' 'M']
# [nan 'D' 'M' 'O' 'N' 'A' 'W']

# %%
# I will pick out the features having more than 75% NaN values
null_f=[]
def null_features(col):
    for i in col:
        if df[i].isnull().sum()/len(df) > 0.75:
            null_f.append(i)

# %%
null_features(df.columns)

# %%
null_f
# Out:
# ['contraband_found',
#  'contraband_drugs',
#  'contraband_weapons',
#  'contraband_alcohol',
#  'contraband_other',
#  'search_basis',
#  'reason_for_search',
#  'raw_SearchResultOne',
#  'raw_SearchResultTwo',
#  'raw_SearchResultThree']

# %%
print_unique(null_f)
# Out:
# [nan False True]
# [nan False True]
# [nan False True]
# [nan False True]
# [nan False True]
# [nan 'other' 'probable cause' 'plain view']
# [nan 'Inventory/Tow' 'Odor of Drugs/Alcohol'
#  'Incident to Arrest|Terry Frisk' 'Incident to Arrest|Inventory/Tow'
#  'Incident to Arrest' 'Odor of Drugs/Alcohol|Incident to Arrest'
#  'Terry Frisk' 'Probable Cause' 'Reasonable Suspicion'
#  'Plain View|Incident to Arrest|Inventory/Tow'
#  'Incident to Arrest|Probable Cause|Plain View'
#  'Probable Cause|Incident to Arrest|Terry Frisk'
#  'Probable Cause|Odor of Drugs/Alcohol|Terry Frisk' 'Plain View'
#  'Odor of Drugs/Alcohol|Terry Frisk|Incident to Arrest'
#  'Incident to Arrest|Plain View|Odor of Drugs/Alcohol'
#  'Plain View|Odor of Drugs/Alcohol|Inventory/Tow'
#  'Inventory/Tow|Incident to Arrest' 'Odor of Drugs/Alcohol|Terry Frisk'
#  'Plain View|Incident to Arrest' 'Odor of Drugs/Alcohol|Probable Cause'
#  'Probable Cause|Odor of Drugs/Alcohol' 'Incident to Arrest|Plain View'
#  'Incident to Arrest|Odor of Drugs/Alcohol'
#  'Incident to Arrest|Terry Frisk|Inventory/Tow'
#  'Incident to Arrest|Terry Frisk|Odor of Drugs/Alcohol'
#  'Probable Cause|Terry Frisk' 'Reasonable Suspicion|Terry Frisk'
#  'Odor of Drugs/Alcohol|Inventory/Tow'
#  'Odor of Drugs/Alcohol|Probable Cause|Incident to Arrest'
#  'Probable Cause|Odor of Drugs/Alcohol|Incident to Arrest'
#  'Odor of Drugs/Alcohol|Incident to Arrest|Probable Cause'
#  'Odor of Drugs/Alcohol|Incident to Arrest|Inventory/Tow'
#  'Terry Frisk|Inventory/Tow'
#  'Reasonable Suspicion|Terry Frisk|Probable Cause'
#  'Probable Cause|Inventory/Tow' 'Plain View|Probable Cause'
#  'Inventory/Tow|Terry Frisk'
#  'Incident to Arrest|Probable Cause|Odor of Drugs/Alcohol'
#  'Odor of Drugs/Alcohol|Plain View' 'Terry Frisk|Incident to Arrest'
#  'Odor of Drugs/Alcohol|Plain View|Reasonable Suspicion'
#  'Incident to Arrest|Plain View|Inventory/Tow'
#  'Terry Frisk|Reasonable Suspicion'
#  'Incident to Arrest|Odor of Drugs/Alcohol|Inventory/Tow'
#  'Terry Frisk|Odor of Drugs/Alcohol|Reasonable Suspicion'
#  'Incident to Arrest|Probable Cause|Terry Frisk'
#  'Incident to Arrest|Inventory/Tow|Plain View'
#  'Reasonable Suspicion|Incident to Arrest'
#  'Probable Cause|Incident to Arrest'
#  'Odor of Drugs/Alcohol|Reasonable Suspicion'
#  'Odor of Drugs/Alcohol|Probable Cause|Reasonable Suspicion'
#  'Probable Cause|Terry Frisk|Odor of Drugs/Alcohol'
#  'Incident to Arrest|Probable Cause'
#  'Probable Cause|Plain View|Odor of Drugs/Alcohol'
#  'Probable Cause|Terry Frisk|Reasonable Suspicion'
#  'Terry Frisk|Odor of Drugs/Alcohol|Incident to Arrest'
#  'Terry Frisk|Probable Cause' 'Probable Cause|Reasonable Suspicion'
#  'Incident to Arrest|Probable Cause|Inventory/Tow'
#  'Reasonable Suspicion|Plain View|Terry Frisk'
#  'Terry Frisk|Odor of Drugs/Alcohol'
#  'Probable Cause|Plain View|Inventory/Tow'
#  'Probable Cause|Incident to Arrest|Inventory/Tow'
#  'Reasonable Suspicion|Odor of Drugs/Alcohol'
#  'Plain View|Odor of Drugs/Alcohol|Terry Frisk'
#  'Terry Frisk|Odor of Drugs/Alcohol|Probable Cause'
#  'Odor of Drugs/Alcohol|Terry Frisk|Reasonable Suspicion'
#  'Incident to Arrest|Odor of Drugs/Alcohol|Terry Frisk'
#  'Terry Frisk|Incident to Arrest|Inventory/Tow'
#  'Plain View|Incident to Arrest|Terry Frisk'
#  'Incident to Arrest|Reasonable Suspicion'
#  'Inventory/Tow|Reasonable Suspicion'
#  'Incident to Arrest|Inventory/Tow|Reasonable Suspicion'
#  'Incident to Arrest|Inventory/Tow|Probable Cause'
#  'Terry Frisk|Inventory/Tow|Incident to Arrest'
#  'Incident to Arrest|Odor of Drugs/Alcohol|Plain View'
#  'Incident to Arrest|Odor of Drugs/Alcohol|Reasonable Suspicion'
#  'Probable Cause|Terry Frisk|Inventory/Tow'
#  'Terry Frisk|Incident to Arrest|Reasonable Suspicion'
#  'Odor of Drugs/Alcohol|Probable Cause|Terry Frisk'
#  'Incident to Arrest|Terry Frisk|Probable Cause'
#  'Probable Cause|Plain View'
#  'Terry Frisk|Probable Cause|Incident to Arrest'
#  'Inventory/Tow|Plain View|Probable Cause'
#  'Probable Cause|Terry Frisk|Incident to Arrest'
#  'Probable Cause|Reasonable Suspicion|Terry Frisk'
#  'Odor of Drugs/Alcohol|Reasonable Suspicion|Terry Frisk'
#  'Incident to Arrest|Reasonable Suspicion|Terry Frisk'
#  'Terry Frisk|Reasonable Suspicion|Incident to Arrest'
#  'Odor of Drugs/Alcohol|Reasonable Suspicion|Probable Cause'
#  'Terry Frisk|Reasonable Suspicion|Probable Cause'
#  'Terry Frisk|Reasonable Suspicion|Inventory/Tow'
#  'Incident to Arrest|Terry Frisk|Reasonable Suspicion'
#  'Plain View|Odor of Drugs/Alcohol'
#  'Incident to Arrest|Reasonable Suspicion|Probable Cause'
#  'Terry Frisk|Odor of Drugs/Alcohol|Inventory/Tow'
#  'Odor of Drugs/Alcohol|Probable Cause|Inventory/Tow'
#  'Plain View|Terry Frisk'
#  'Incident to Arrest|Inventory/Tow|Odor of Drugs/Alcohol'
#  'Inventory/Tow|Plain View'
#  'Incident to Arrest|Reasonable Suspicion|Inventory/Tow'
#  'Incident to Arrest|Odor of Drugs/Alcohol|Probable Cause'
#  'Terry Frisk|Probable Cause|Reasonable Suspicion'
#  'Terry Frisk|Incident to Arrest|Odor of Drugs/Alcohol'
#  'Odor of Drugs/Alcohol|Incident to Arrest|Reasonable Suspicion'
#  'Probable Cause|Terry Frisk|Plain View'
#  'Odor of Drugs/Alcohol|Probable Cause|Plain View'
#  'Plain View|Probable Cause|Incident to Arrest'
#  'Probable Cause|Odor of Drugs/Alcohol|Plain View'
#  'Probable Cause|Inventory/Tow|Plain View'
#  'Probable Cause|Plain View|Incident to Arrest'
#  'Odor of Drugs/Alcohol|Incident to Arrest|Terry Frisk'
#  'Terry Frisk|Plain View'
#  'Odor of Drugs/Alcohol|Inventory/Tow|Incident to Arrest'
#  'Reasonable Suspicion|Inventory/Tow|Incident to Arrest'
#  'Incident to Arrest|Terry Frisk|Plain View' 'Plain View|Inventory/Tow'
#  'Reasonable Suspicion|Probable Cause' 'Plain View|Reasonable Suspicion'
#  'Terry Frisk|Plain View|Odor of Drugs/Alcohol'
#  'Terry Frisk|Plain View|Incident to Arrest'
#  'Terry Frisk|Probable Cause|Odor of Drugs/Alcohol'
#  'Incident to Arrest|Inventory/Tow|Terry Frisk'
#  'Reasonable Suspicion|Probable Cause|Incident to Arrest'
#  'Inventory/Tow|Probable Cause'
#  'Odor of Drugs/Alcohol|Plain View|Terry Frisk'
#  'Probable Cause|Reasonable Suspicion|Inventory/Tow'
#  'Reasonable Suspicion|Incident to Arrest|Inventory/Tow'
#  'Terry Frisk|Probable Cause|Inventory/Tow'
#  'Odor of Drugs/Alcohol|Terry Frisk|Probable Cause'
#  'Plain View|Odor of Drugs/Alcohol|Probable Cause'
#  'Inventory/Tow|Odor of Drugs/Alcohol'
#  'Incident to Arrest|Probable Cause|Reasonable Suspicion'
#  'Odor of Drugs/Alcohol|Reasonable Suspicion|Inventory/Tow'
#  'Reasonable Suspicion|Plain View'
#  'Probable Cause|Odor of Drugs/Alcohol|Reasonable Suspicion'
#  'Plain View|Incident to Arrest|Probable Cause'
#  'Plain View|Odor of Drugs/Alcohol|Reasonable Suspicion'
#  'Plain View|Probable Cause|Reasonable Suspicion'
#  'Plain View|Terry Frisk|Odor of Drugs/Alcohol'
#  'Odor of Drugs/Alcohol|Plain View|Probable Cause'
#  'Odor of Drugs/Alcohol|Plain View|Incident to Arrest'
#  'Incident to Arrest|Reasonable Suspicion|Odor of Drugs/Alcohol'
#  'Probable Cause|Inventory/Tow|Incident to Arrest'
#  'Plain View|Odor of Drugs/Alcohol|Incident to Arrest'
#  'Probable Cause|Plain View|Terry Frisk'
#  'Reasonable Suspicion|Plain View|Probable Cause'
#  'Odor of Drugs/Alcohol|Plain View|Inventory/Tow'
#  'Probable Cause|Odor of Drugs/Alcohol|Inventory/Tow'
#  'Inventory/Tow|Incident to Arrest|Probable Cause'
#  'Plain View|Terry Frisk|Probable Cause'
#  'Reasonable Suspicion|Inventory/Tow|Odor of Drugs/Alcohol'
#  'Plain View|Terry Frisk|Incident to Arrest'
#  'Odor of Drugs/Alcohol|Reasonable Suspicion|Plain View'
#  'Incident to Arrest|Plain View|Probable Cause'
#  'Odor of Drugs/Alcohol|Terry Frisk|Inventory/Tow'
#  'Odor of Drugs/Alcohol|Inventory/Tow|Reasonable Suspicion'
#  'Terry Frisk|Reasonable Suspicion|Odor of Drugs/Alcohol'
#  'Reasonable Suspicion|Inventory/Tow'
#  'Plain View|Reasonable Suspicion|Odor of Drugs/Alcohol'
#  'Probable Cause|Reasonable Suspicion|Odor of Drugs/Alcohol'
#  'Reasonable Suspicion|Probable Cause|Odor of Drugs/Alcohol'
#  'Probable Cause|Incident to Arrest|Odor of Drugs/Alcohol'
#  'Odor of Drugs/Alcohol|Incident to Arrest|Plain View'
#  'Odor of Drugs/Alcohol|Reasonable Suspicion|Incident to Arrest'
#  'Inventory/Tow|Probable Cause|Reasonable Suspicion'
#  'Inventory/Tow|Incident to Arrest|Odor of Drugs/Alcohol'
#  'Inventory/Tow|Probable Cause|Odor of Drugs/Alcohol'
#  'Probable Cause|Reasonable Suspicion|Plain View'
#  'Odor of Drugs/Alcohol|Inventory/Tow|Probable Cause'
#  'Plain View|Probable Cause|Odor of Drugs/Alcohol'
#  'Reasonable Suspicion|Odor of Drugs/Alcohol|Plain View'
#  'Probable Cause|Inventory/Tow|Odor of Drugs/Alcohol'
#  'Reasonable Suspicion|Odor of Drugs/Alcohol|Probable Cause'
#  'Reasonable Suspicion|Odor of Drugs/Alcohol|Inventory/Tow'
#  'Reasonable Suspicion|Odor of Drugs/Alcohol|Incident to Arrest'
#  'Probable Cause|Plain View|Reasonable Suspicion'
#  'Reasonable Suspicion|Probable Cause|Terry Frisk'
#  'Inventory/Tow|Odor of Drugs/Alcohol|Reasonable Suspicion'
#  'Inventory/Tow|Odor of Drugs/Alcohol|Probable Cause'
#  'Inventory/Tow|Odor of Drugs/Alcohol|Plain View'
#  'Reasonable Suspicion|Incident to Arrest|Odor of Drugs/Alcohol'
#  'Plain View|Reasonable Suspicion|Terry Frisk'
#  'Plain View|Incident to Arrest|Odor of Drugs/Alcohol'
#  'Inventory/Tow|Odor of Drugs/Alcohol|Incident to Arrest'
#  'Plain View|Probable Cause|Inventory/Tow'
#  'Reasonable Suspicion|Incident to Arrest|Probable Cause']
# [nan 'N' 'D' 'M' 'A' 'W' 'O']
# [nan 'W' 'D' 'A' 'O' 'M']
# [nan 'D' 'M' 'O' 'N' 'A' 'W']

# %%
df.drop(null_f[-4],axis=1, inplace=True)
null_f.pop(-4)
# Out:
# 'reason_for_search'

# %%
null_f
# Out:
# ['contraband_found',
#  'contraband_drugs',
#  'contraband_weapons',
#  'contraband_alcohol',
#  'contraband_other',
#  'search_basis',
#  'raw_SearchResultOne',
#  'raw_SearchResultTwo',
#  'raw_SearchResultThree']

# %%
print_unique(null_f)
# Out:
# [nan False True]
# [nan False True]
# [nan False True]
# [nan False True]
# [nan False True]
# [nan 'other' 'probable cause' 'plain view']
# [nan 'N' 'D' 'M' 'A' 'W' 'O']
# [nan 'W' 'D' 'A' 'O' 'M']
# [nan 'D' 'M' 'O' 'N' 'A' 'W']

# %%
df[null_f].head()
# Out:
#   contraband_found contraband_drugs contraband_weapons contraband_alcohol  \
# 0              NaN              NaN                NaN                NaN
# 1              NaN              NaN                NaN                NaN
# 2              NaN              NaN                NaN                NaN
# 3              NaN              NaN                NaN                NaN
# 4              NaN              NaN                NaN                NaN
#
#   contraband_other search_basis raw_SearchResultOne raw_SearchResultTwo  \
# 0              NaN          NaN                 NaN                 NaN
# 1              NaN          NaN                 NaN                 NaN
# 2              NaN          NaN                 NaN                 NaN
# 3              NaN          NaN                 NaN                 NaN
# 4              NaN          NaN                 NaN                 NaN
#
#   raw_SearchResultThree
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df[null_f].dtypes
# Out:
# contraband_found         object
# contraband_drugs         object
# contraband_weapons       object
# contraband_alcohol       object
# contraband_other         object
# search_basis             object
# raw_SearchResultOne      object
# raw_SearchResultTwo      object
# raw_SearchResultThree    object
# dtype: object

# %%
# I will replace the NaNs with 0 and make a new category out of it or using my domain knowedge i will replace some with mode for that particular features

# %%
df[null_f].iloc[:,-4]=df[null_f].iloc[:,-4].fillna(value="other")
null_f.pop(-4)
# Out:
# 'search_basis'

# %%
df[null_f]=df[null_f].fillna(value="missing")

# %%
df[null_f]
# Out:
#        contraband_found contraband_drugs contraband_weapons  \
# 0               missing          missing            missing
# 1               missing          missing            missing
# 2               missing          missing            missing
# 3               missing          missing            missing
# 4               missing          missing            missing
# ...                 ...              ...                ...
# 509676          missing          missing            missing
# 509677          missing          missing            missing
# 509678          missing          missing            missing
# 509679          missing          missing            missing
# 509680          missing          missing            missing
#
#        contraband_alcohol contraband_other raw_SearchResultOne  \
# 0                 missing          missing             missing
# 1                 missing          missing             missing
# 2                 missing          missing             missing
# 3                 missing          missing             missing
# 4                 missing          missing             missing
# ...                   ...              ...                 ...
# 509676            missing          missing             missing
# 509677            missing          missing             missing
# 509678            missing          missing             missing
# 509679            missing          missing             missing
# 509680            missing          missing             missing
#
#        raw_SearchResultTwo raw_SearchResultThree
# 0                  missing               missing
# 1                  missing               missing
# 2                  missing               missing
# 3                  missing               missing
# 4                  missing               missing
# ...                    ...                   ...
# 509676             missing               missing
# 509677             missing               missing
# 509678             missing               missing
# 509679             missing               missing
# 509680             missing               missing
#
# [509681 rows x 8 columns]

# %%
# changing data type for the categorical variable
df[categorical]= df[categorical].astype("category")
df.dtypes
# Out:
# raw_row_number              int64
# date                       object
# time                       object
# zone                     category
# subject_race             category
# subject_sex              category
# department_id              object
# type                     category
# arrest_made              category
# citation_issued          category
# warning_issued           category
# outcome                  category
# contraband_found         category
# contraband_drugs         category
# contraband_weapons       category
# contraband_alcohol       category
# contraband_other         category
# frisk_performed          category
# search_conducted         category
# search_basis             category
# reason_for_stop          category
# vehicle_make               object
# vehicle_model              object
# raw_BasisForStop         category
# raw_OperatorRace         category
# raw_OperatorSex          category
# raw_ResultOfStop         category
# raw_SearchResultOne      category
# raw_SearchResultTwo      category
# raw_SearchResultThree    category
# dtype: object

# %%
df.isnull().sum()
# Out:
# raw_row_number                0
# date                         10
# time                         10
# zone                         10
# subject_race              29073
# subject_sex               29097
# department_id                10
# type                          0
# arrest_made               29073
# citation_issued           29073
# warning_issued            29073
# outcome                   35841
# contraband_found              0
# contraband_drugs              0
# contraband_weapons            0
# contraband_alcohol            0
# contraband_other              0
# frisk_performed              10
# search_conducted              0
# search_basis             491919
# reason_for_stop           29073
# vehicle_make             191564
# vehicle_model            279593
# raw_BasisForStop          29073
# raw_OperatorRace          29073
# raw_OperatorSex           29073
# raw_ResultOfStop          29073
# raw_SearchResultOne           0
# raw_SearchResultTwo           0
# raw_SearchResultThree         0
# dtype: int64

# %%
df[]
# Out:
#   File "<ipython-input-242-71f11347ebfc>", line 1
#     df[]
#        ^
# SyntaxError: invalid syntax
